# %%
# Packages 
import pandas as pd 
from autoc import DataExploration,NaImputer
#from autoc.utils

# %pylab inline --no-import
import pylab as pl
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

# Seaborn options 
sns.set_palette("deep", desat=.6)
sns.set_context(rc={"figure.figsize": (8, 4)})
plt.style.use('ggplot') # ggplot2 style for mathplotlib 

# path to cleaned datasets 
path_reviews_cleaned = '~/Google Drive/Auto_clean/Datasets/Glassdoor/'
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-10-2985428c02d9> in <module>()
#       1 # Packages
#       2 import pandas as pd
# ----> 3 from autoc import DataExploration,NaImputer
#       4 #from autoc.utils
#       5
#
# ImportError: cannot import name DataExploration

# %%
from autoc.explorer import DataExploration
from autoc.

# %%
df_reviews = pd.read_csv(path_reviews_cleaned + 'glassdoor_reviews_cleaned_utf8_170415.csv')

# %%
df_reviews.head()
# Out:
#              website  interview_difficulty               ceo_name  nb_c_jobs  \
# 0     www.target.com                   2.8          Brian Cornell        NaN
# 1  www.homedepot.com                   2.3           Craig Menear       1700
# 2       www.army.mil                   2.3            John McHugh        NaN
# 3        www.att.com                   2.7  Randall L. Stephenson       2100
# 4    www.bestbuy.com                   2.4            Hubert Joly        NaN
#
#                                  company_description registered_employer  \
# 0  From our Minneapolis-based headquarters to ove...    Engaged Employer
# 1                                                NaN    Engaged Employer
# 2  The US Department of the Army has its marching...    Engaged Employer
# 3  We understand that our customers want an easie...                 NaN
# 4  The biggest consumer electronics outlet in the...    Engaged Employer
#
#    benefits_below                                  similar_companies  \
# 0             NaN  Walmart,The Home Depot,Walgreens,Macy's,Bank o...
# 1             NaN                                                NaN
# 2             NaN  Walmart,US Navy,The Home Depot,UPS,Bank of Ame...
# 3             NaN                                                NaN
# 4             NaN  Walmart,The Home Depot,AT&T,Lowe's,Target,Bank...
#
#   acquired_by  founded   ...    \
# 0         NaN     1962   ...
# 1         NaN     1978   ...
# 2         NaN     1775   ...
# 3         NaN     1876   ...
# 4         NaN     1966   ...
#
#                                               awards  ceo_rating  \
# 0  Best Companies for Hourly Workers,Working Moth...          66
# 1  World's Most Admired Companies of 2013,Fortune...          80
# 2  Best Places to Work for Commuters,National Cen...          77
# 3  Happiest Companies for Young Professionals,For...          71
# 4  Employees’ Choice -50 Best Places to Work,Glas...          74
#
#                            type            industry operated_by  \
# 0  Company - Public with Ticker              Retail         NaN
# 1  Company - Public with Ticker              Retail         NaN
# 2                    Government          Government         NaN
# 3  Company - Public with Ticker  Telecommunications         NaN
# 4  Company - Public with Ticker              Retail         NaN
#
#    headquarters_city  headquarters_state nb_awards_after_2000  has_website  \
# 0        Minneapolis                  MN                    2            1
# 1            Atlanta                  GA                    6            1
# 2         Washington                  DC                    2            1
# 3             Dallas                  TX                    5            1
# 4          Richfield                  MN                    2            1
#
#    ticker
# 0     TGT
# 1      HD
# 2     NaN
# 3       T
# 4     BBY
#
# [5 rows x 35 columns]

# %%
missing_map(df_reviews, nmax=1000)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-fa7774e5eb50> in <module>()
# ----> 1 missing_map(df_reviews, nmax=1000)
#
# NameError: name 'missing_map' is not defined
